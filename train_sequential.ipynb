# %% [markdown]
# # Hotel Reservation Chatbot Using Deep Learning
#
# This project implements a hotel reservation chatbot using a deep learning model built with TensorFlow and Keras. The chatbot is trained on a dataset containing various intents related to hotel bookings and interactions, enabling it to respond intelligently to user inquiries.
#
# ### Difference from the Previous Implementation
#
# In this version of the chatbot, we used a Sequential model provided by Keras, which is a high-level neural network API that allows us to easily build and train models. This approach is different from the previous one where we implemented a **custom Simple Recurrent Neural Network (RNN)**.
#
# While the custom RNN implementation gave us more control over the model architecture, training, and backpropagation, it was more complex and involved manual coding for key operations such as the forward and backward passes.
#
# In contrast, using Keras and the Sequential model provides a more streamlined, efficient, and accessible way to design and train the chatbot’s neural network. The Keras Sequential API is designed for simpler models, especially when the model is built layer by layer in a linear stack. It allows us to leverage built-in layers like **Embedding**, **GlobalAveragePooling1D**, and **Dense**, which simplifies the process of defining and training the model.
#
# ### Why Use Keras and TensorFlow?
#
# - **Ease of Use**: The Sequential API is easy to understand and use, making it more suitable for rapid prototyping and deployment.
# - **Efficiency**: Keras and TensorFlow offer highly optimized operations and efficient training algorithms.
# - **Flexibility**: Despite being high-level, Keras also allows for easy customization if needed, providing a good balance of abstraction and flexibility.
#
# This implementation allows us to focus on improving the chatbot's functionality without getting bogged down by low-level details, which is ideal for production environments where we need fast iteration and reliable performance.

# %% [markdown]
# This part of the code imports the necessary libraries and modules required to build, train, and evaluate the chatbot using a machine learning model. Here's a description of each library/module:
#
# 1. **`json`**:
#    The `json` module is used to work with JSON data, including reading and writing JSON files. In this case, it's used to load the chatbot's dataset (`intents.json`), which is stored in JSON format.
#
# 2. **`numpy`**:
#    `numpy` is a popular library for numerical computing in Python. It provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays. It is used in this project for handling data structures such as arrays and matrices during preprocessing and model training.
#
# 3. **`tensorflow` and `keras`**:
#    - **`tensorflow`** is an open-source machine learning framework developed by Google. It provides tools for building and deploying machine learning models.
#    - **`keras`** is a high-level neural networks API, written in Python, and is now part of TensorFlow. It simplifies the process of building and training deep learning models. In this code, Keras is used to define and train the neural network model for the chatbot.
#
# 4. **`Sequential`**:
#    `Sequential` is a class in Keras that allows for the easy construction of models where the layers are stacked in a linear sequence. It is used to create a linear model by adding layers one by one.
#
# 5. **`Dense`, `Embedding`, `GlobalAveragePooling1D`**:
#    - **`Dense`** is a fully connected neural network layer, often used as the final layer in a model. It connects every neuron in the layer to every neuron in the previous layer.
#    - **`Embedding`** is a layer that converts integer-encoded words into dense vectors of fixed size, typically used to represent words in a lower-dimensional space.
#    - **`GlobalAveragePooling1D`** is a pooling layer that calculates the average of the entire sequence along the time dimension, which helps reduce the dimensionality of the model while retaining important features.
#
# 6. **`Tokenizer` and `pad_sequences` from `tensorflow.keras.preprocessing.text`**:
#    - **`Tokenizer`** is a Keras utility that helps tokenize text, i.e., convert text into sequences of integers, each representing a word or a token. This is useful for text preprocessing before feeding the data into the model.
#    - **`pad_sequences`** is used to ensure that all sequences have the same length by padding shorter sequences with zeros (or another constant value) at the beginning or end, ensuring uniform input length for the model.
#
# 7. **`LabelEncoder` from `sklearn.preprocessing`**:
#    `LabelEncoder` is a part of the scikit-learn library, and it is used to encode categorical labels (such as the intent tags) into numeric values. This is needed because machine learning models work with numerical values, not textual labels.
#
# In summary, these libraries and modules provide the essential functionality for data preprocessing, model building, training, and evaluation in the chatbot application.

# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
# Out:
# C:\Users\nisha\AppData\Roaming\Python\Python39\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# This part of the code is responsible for loading the `intents.json` dataset, which contains the patterns (user inputs), tags (categories or intents), and the corresponding responses (bot replies). Here's the description of what happens in this code:
#
# 1. **Opening the JSON File**:
#    The code uses Python's built-in `open()` function to open the `intents2.json` file located at the specified file path. The `encoding='utf-8'` ensures that the file is read using UTF-8 encoding, which is commonly used to handle special characters or non-ASCII text in the file.
#
# 2. **Loading the Data**:
#    The `json.load()` function is used to parse the content of the JSON file into a Python dictionary. The `data` variable now holds the entire content of the `intents2.json` file as a dictionary, where the structure of the data is typically a list of intents, each containing:
#    - `tag`: The label associated with the intent.
#    - `patterns`: A list of possible user inputs related to that intent.
#    - `responses`: A list of responses that the chatbot will use when the intent is recognized.
#
# In essence, this code reads the `intents2.json` file and converts its content into a Python dictionary, which will be used in subsequent steps to train and test the chatbot model.

# %%
with open('C:/Users/nisha/Downloads/CHATBOT-20241115T051416Z-001/CHATBOT/intents2.json', encoding='utf-8') as data_file:
    data = json.load(data_file)

# %% [markdown]
# This section of the code processes the `intents.json` file to extract relevant information for training the chatbot model. It organizes the sentences, labels (tags), responses, and the list of unique tags for the classification task. Here's a step-by-step breakdown:
#
# 1. **Initialization of Lists**:
#    - `training_sentences`: This list will store all the user input patterns (e.g., questions or statements) that the chatbot will learn from.
#    - `training_labels`: This list will store the corresponding tags (labels) for each user input, which are used to categorize the inputs into different classes.
#    - `labels`: This list will store all unique tags present in the dataset, ensuring that each tag is only stored once.
#    - `responses`: This list will store the predefined responses associated with each tag, which the chatbot will use to reply based on the predicted tag.
#
# 2. **Looping Through Intents**:
#    The code iterates through each intent in the dataset:
#    - **Extracting Patterns and Tags**:
#      Each intent contains multiple `patterns` (phrases or questions a user might ask), and each pattern is associated with a `tag` (which is essentially the intent's label). The code appends each pattern to `training_sentences` and the associated tag to `training_labels`.
#
#    - **Handling Responses**:
#      Each intent may also contain a list of `responses` (possible chatbot replies for that intent). If the `responses` key exists for the current intent, it is appended to the `responses` list. If it does not exist, an empty list is added (to avoid errors during processing).
#
#    - **Storing Unique Tags**:
#      For each intent, the tag is added to the `labels` list if it is not already present. This ensures that the `labels` list will only contain unique tags from all intents.
#
# 3. **Calculating Number of Classes**:
#    After collecting all the unique tags, the `num_classes` variable is calculated by finding the length of the `labels` list. This represents the total number of unique intents that the chatbot needs to classify, which will be used for the output layer of the neural network model.
#
# In summary, this section of the code processes the intent data to extract the necessary components (patterns, tags, and responses) for training the chatbot. It prepares the input data and labels for further processing in the machine learning pipeline.

# %%
training_sentences = []
training_labels = []
labels = []
responses = []

for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    
    # Check if 'responses' key exists before appending
    if 'responses' in intent:
        responses.append(intent['responses'])
    else:
        responses.append([])  # Append an empty list if 'responses' is missing
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])

num_classes = len(labels)

# %% [markdown]
# This section of the code is responsible for encoding the labels (or tags) associated with each training sentence into numerical values, which is a necessary step when working with machine learning models that require numerical input.
#
# 1. **LabelEncoder Initialization**:
#    The `LabelEncoder` from the `sklearn.preprocessing` module is initialized. This encoder is used to convert categorical labels (in this case, the tags associated with each sentence) into numerical values.
#
# 2. **Fitting the Encoder**:
#    The `fit()` method is called on the `LabelEncoder` with the list of training labels (`training_labels`). This step allows the encoder to learn the unique tags in the dataset and assign each tag a unique integer. The encoder essentially maps each tag to an index, e.g., if the tags are ['greeting', 'goodbye', 'information'], they might be mapped to [0, 1, 2].
#
# 3. **Transforming Labels**:
#    After fitting, the `transform()` method is applied to the `training_labels`. This converts the original categorical tags (such as 'greeting', 'goodbye', etc.) into their corresponding numerical labels (e.g., 0, 1, 2). The `training_labels` list is now converted from a list of strings to a list of integers, which can be fed into the neural network model for classification.
#
# In summary, this process ensures that the categorical labels (tags) in the dataset are transformed into a numerical format that the model can understand, enabling the model to perform classification tasks.

# %%
lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)

# %% [markdown]
# This section of the code is responsible for preprocessing the text data, specifically the user input sentences, before feeding them into the neural network model. Here's a breakdown of each step:
#
# 1. **Vocabulary and Sequence Setup**:
#    The vocabulary size (`vocab_size`) is set to 1000, which means only the top 1000 most frequent words in the dataset will be considered. Any words that are less frequent will be ignored. This helps in reducing the complexity of the model. Additionally, an "out-of-vocabulary" token (`oov_token`) is introduced to handle words that are not found in the training data.
#
# 2. **Tokenization**:
#    The `Tokenizer` is used to convert each word in the sentences into a unique integer. This step transforms text into numerical sequences, where each word corresponds to an index based on its frequency in the training data. The tokenizer is trained using the provided training sentences, allowing it to learn the frequency of each word and create a word index.
#
# 3. **Sequence Transformation**:
#    After the tokenizer is trained, the sentences are transformed into sequences of integers. Each word in the sentence is replaced with its corresponding integer from the word index. If a word is not found in the index, it is replaced with the `<OOV>` token.
#
# 4. **Padding and Truncating Sequences**:
#    Since different sentences have different lengths, padding and truncating are applied to make all sequences the same length. In this case, the maximum sequence length is set to 20. Sentences shorter than this length are padded with zeros, while sentences longer than this length are truncated from the end. This ensures that all input sequences have the same shape, which is required for feeding them into a neural network.
#
# These steps collectively ensure that the text data is transformed into a suitable format (numerical sequences of consistent length) for input to the machine learning model, facilitating the model's training and inference processes.

# %%
vocab_size = 1000
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token) # adding out of vocabulary token
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %% [markdown]
# ### Description of Code
#
# This part of the code defines a machine learning model using Keras, a high-level API for building neural networks. The model architecture is as follows:
#
# 1. **`Sequential()`**:
#    The model is instantiated using Keras' `Sequential` class, which allows for the addition of layers in a linear stack. Each layer has one input and one output, and they are stacked sequentially from input to output.
#
# 2. **`Embedding(vocab_size, embedding_dim, input_length=max_len)`**:
#    - This is the **embedding layer**. It converts the input tokens (integers representing words) into dense vectors of fixed size.
#    - `vocab_size`: The size of the vocabulary (total number of unique words in the dataset).
#    - `embedding_dim`: The dimension of the dense word embeddings (a hyperparameter, often chosen based on experimentation).
#    - `input_length=max_len`: The maximum length of the input sequences, ensuring that all sequences have the same length.
#
# 3. **`GlobalAveragePooling1D()`**:
#    This is a **pooling layer** that applies **global average pooling** across the time dimension (sequence length). It computes the average of all the word embeddings in a sequence, reducing the sequence to a fixed-size vector representation, regardless of the sequence length. This helps reduce the model's complexity by lowering the dimensionality of the data.
#
# 4. **`Dense(16, activation='relu')`**:
#    A **fully connected (dense) layer** with 16 neurons and the **ReLU** activation function. The ReLU function (Rectified Linear Unit) introduces non-linearity and helps the model learn complex patterns. This layer is used twice to increase the model's capacity to learn from the data.
#
# 5. **`Dense(num_classes, activation='softmax')`**:
#    The final output layer is also a **dense layer** with a number of units equal to the number of output classes (i.e., intent categories).
#    - **Softmax activation** is applied, which normalizes the output so that the values are probabilities that sum to 1. Each value represents the model’s confidence that a given input belongs to a particular class (intent).
#
# 6. **`model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])`**:
#    - **`loss='sparse_categorical_crossentropy'`**: The loss function used here is sparse categorical cross-entropy, which is appropriate for multi-class classification problems where the target labels are integers (rather than one-hot encoded).
#    - **`optimizer='adam'`**: The Adam optimizer is used for updating the model weights during training. Adam is a widely used optimizer due to its adaptive learning rate and efficiency.
#    - **`metrics=['accuracy']`**: The model will track accuracy during training, which will help evaluate the model's performance.
#
# In summary, this model architecture is designed for text classification, where the goal is to predict an intent (category) for a given user input. The architecture uses embedding to convert words into vectors, followed by a pooling layer and several dense layers for classification. The model is compiled with a sparse categorical cross-entropy loss function, and the Adam optimizer is used for training.

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# C:\Users\nisha\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
pip install --upgrade tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\nisha\appdata\roaming\python\python39\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (61.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.12.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.66.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.45.0)
# Requirement already satisfied: rich in c:\users\nisha\appdata\roaming\python\python39\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in c:\users\nisha\appdata\roaming\python\python39\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\nisha\appdata\roaming\python\python39\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2021.10.8)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.18.0->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nisha\appdata\roaming\python\python39\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Model Summary
#
# The model summary provides detailed information about the architecture of the neural network, including the layers, their output shapes, the number of parameters, and whether the parameters are trainable.
#
# Here’s the breakdown of each layer:
#
# 1. **Embedding Layer**:
#    - **Output Shape**: `(None, 20, 16)`
#    - **Parameters**: 16,000
#    - The embedding layer converts input sentences into dense vectors of size 16. The input length is fixed at 20, which means the model expects sequences of 20 words or less. If a sentence is shorter than 20 words, it will be padded.
#    - **Total parameters**: 16,000 (The embedding matrix has 1,000 unique words in the vocabulary, each represented by a 16-dimensional vector, so the number of parameters is 1,000 * 16).
#
# 2. **GlobalAveragePooling1D Layer**:
#    - **Output Shape**: `(None, 16)`
#    - **Parameters**: 0
#    - This layer applies global average pooling on the sequence of word embeddings, reducing the sequence from a length of 20 to a single vector of length 16 (the number of features in the embeddings). The number of parameters is 0 because this layer does not have any weights to train.
#
# 3. **Dense Layer (First Dense)**:
#    - **Output Shape**: `(None, 16)`
#    - **Parameters**: 272
#    - This fully connected layer has 16 neurons and applies the ReLU activation function. It takes in the 16-dimensional vector from the pooling layer. The number of parameters here is calculated as `(input_size * number_of_neurons) + number_of_neurons`, which is `(16 * 16) + 16 = 272`.
#
# 4. **Dense Layer (Second Dense)**:
#    - **Output Shape**: `(None, 16)`
#    - **Parameters**: 272
#    - This is another fully connected layer with 16 neurons, following the same structure as the previous dense layer.
#
# 5. **Dense Layer (Output Layer)**:
#    - **Output Shape**: `(None, 15)`
#    - **Parameters**: 255
#    - This final dense layer has 15 neurons (equal to the number of classes in the intent classification task), and it uses the **softmax** activation function to output probabilities for each of the possible classes. The number of parameters here is `(input_size * number_of_neurons) + number_of_neurons`, which is `(16 * 15) + 15 = 255`.
#
# ### Total Parameters:
# - **Total Parameters**: 50,399 (196.88 KB)
# - **Trainable Parameters**: 16,799 (65.62 KB)
# - **Non-Trainable Parameters**: 0 (0.00 B)
#
# The total number of parameters is 50,399, but only 16,799 are trainable because the embedding weights and the dense layer weights are trainable, while the pooling layer has no weights to train.
#
# ### Optimizer Params:
# - **Optimizer Params**: 33,600 (131.25 KB)
# - The optimizer parameters are separate from the model's trainable parameters. These are used by the Adam optimizer to update the model weights during training.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 20, 16)              │          16,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling1d             │ (None, 16)                  │               0 │
# │ (GlobalAveragePooling1D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 15)                  │             255 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 50,399 (196.88 KB)
#  Trainable params: 16,799 (65.62 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 33,600 (131.25 KB)

# %% [markdown]
# ### Training the Model
#
# 1. **`model.fit()`**:
#    - This method is used to train the model on the data. It takes in the input data (`padded_sequences`), the corresponding target labels (`np.array(training_labels)`), and the number of epochs for which to train the model.
#    - **Input Data (`padded_sequences`)**: The preprocessed and padded sequences of user inputs, which are the training sentences represented as sequences of integers (tokenized words).
#    - **Target Data (`np.array(training_labels)`)**: The labels (intents) corresponding to the training sentences, encoded as integers.
#    - **Epochs**: The number of times the entire dataset is passed through the model during training. In this case, the model will train for 550 epochs. This means the model will go through the entire dataset 550 times, adjusting the weights after each epoch.
#
# 2. **`history`**:
#    - The result of `model.fit()` is stored in the `history` variable. This contains information about the training process, including the loss and accuracy metrics at each epoch. It is useful for plotting the training progress and evaluating the model's performance over time.
#
# #### Key Points:
#
# - **Epochs (550)**: The model will undergo 550 iterations over the entire dataset, updating its weights after each pass.
# - **Training Process**: During each epoch, the model uses the input data (`padded_sequences`) to predict labels and compare them with the true labels (`training_labels`). The loss function calculates the error, and the optimizer (Adam) adjusts the model’s weights accordingly.
#
# This step will train the model to learn the relationships between the user input and its corresponding intent labels, enabling it to classify new user inputs into one of the predefined categories (intents).

# %%
epochs = 550
history = model.fit(padded_sequences, np.array(training_labels), epochs=epochs)
# Out:
# Epoch 1/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0607 - loss: 2.7106
# Epoch 2/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0450 - loss: 2.7080
# Epoch 3/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0607 - loss: 2.7059
# Epoch 4/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2080 - loss: 2.7051
# Epoch 5/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1820 - loss: 2.7040
# Epoch 6/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1698 - loss: 2.7026
# Epoch 7/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2466 - loss: 2.7007
# Epoch 8/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2119 - loss: 2.7005
# Epoch 9/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2084 - loss: 2.6995
# Epoch 10/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1388 - loss: 2.6977
# Epoch 11/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0685 - loss: 2.6968
# Epoch 12/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0528 - loss: 2.6959
# Epoch 13/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0793 - loss: 2.6953
# Epoch 14/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1330 - loss: 2.6924
# Epoch 15/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1291 - loss: 2.6920
# Epoch 16/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1091 - loss: 2.6913
# Epoch 17/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.1781 - loss: 2.6878
# Epoch 18/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1820 - loss: 2.6855
# Epoch 19/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1864 - loss: 2.6831
# Epoch 20/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1369 - loss: 2.6787
# Epoch 21/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1018 - loss: 2.6823
# Epoch 22/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1175 - loss: 2.6784
# Epoch 23/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1174 - loss: 2.6756
# Epoch 24/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1135 - loss: 2.6738
# Epoch 25/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1252 - loss: 2.6728
# Epoch 26/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1174 - loss: 2.6656
# Epoch 27/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1213 - loss: 2.6624
# Epoch 28/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1252 - loss: 2.6663
# Epoch 29/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1330 - loss: 2.6564
# Epoch 30/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1057 - loss: 2.6554
# Epoch 31/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1057 - loss: 2.6563
# Epoch 32/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1135 - loss: 2.6555
# Epoch 33/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.1174 - loss: 2.65207
# Epoch 34/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1174 - loss: 2.6410
# Epoch 35/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1174 - loss: 2.6415
# Epoch 36/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1291 - loss: 2.6248
# Epoch 37/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1369 - loss: 2.6268
# Epoch 38/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1057 - loss: 2.6250
# Epoch 39/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1526 - loss: 2.6054
# Epoch 40/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.1096 - loss: 2.61544
# Epoch 41/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.1291 - loss: 2.6160
# Epoch 42/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.0979 - loss: 2.6218
# Epoch 43/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1778 - loss: 2.6125
# Epoch 44/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1781 - loss: 2.6022
# Epoch 45/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - accuracy: 0.1742 - loss: 2.6081
# Epoch 46/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1585 - loss: 2.6093
# Epoch 47/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1820 - loss: 2.5867
# Epoch 48/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1438 - loss: 2.5894
# Epoch 49/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1291 - loss: 2.5595
# Epoch 50/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1135 - loss: 2.5620
# Epoch 51/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1213 - loss: 2.5696
# Epoch 52/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2128 - loss: 2.5540
# Epoch 53/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2270 - loss: 2.5834
# Epoch 54/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2505 - loss: 2.5466
# Epoch 55/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2383 - loss: 2.5335
# Epoch 56/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3865 - loss: 2.5338
# Epoch 57/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4745 - loss: 2.5316
# Epoch 58/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4164 - loss: 2.5530
# Epoch 59/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3375 - loss: 2.5205
# Epoch 60/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3063 - loss: 2.5363
# Epoch 61/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3028 - loss: 2.5592
# Epoch 62/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3458 - loss: 2.5185
# Epoch 63/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3263 - loss: 2.5076
# Epoch 64/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1859 - loss: 2.5165
# Epoch 65/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1859 - loss: 2.5049
# Epoch 66/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1625 - loss: 2.5290
# Epoch 67/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1937 - loss: 2.4763
# Epoch 68/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1898 - loss: 2.4958
# Epoch 69/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1664 - loss: 2.5054
# Epoch 70/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1742 - loss: 2.5215
# Epoch 71/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2725 - loss: 2.4789
# Epoch 72/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2872 - loss: 2.5229
# Epoch 73/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3302 - loss: 2.4597
# Epoch 74/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2872 - loss: 2.4999
# Epoch 75/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3146 - loss: 2.4764
# Epoch 76/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2808 - loss: 2.4506
# Epoch 77/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2040 - loss: 2.4971
# Epoch 78/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1737 - loss: 2.4608
# Epoch 79/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1932 - loss: 2.4494
# Epoch 80/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2348 - loss: 2.4176
# Epoch 81/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2803 - loss: 2.4709
# Epoch 82/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2794 - loss: 2.4786
# Epoch 83/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3379 - loss: 2.4403
# Epoch 84/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2907 - loss: 2.4738
# Epoch 85/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3618 - loss: 2.4331
# Epoch 86/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3904 - loss: 2.43269
# Epoch 87/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4159 - loss: 2.4609
# Epoch 88/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.4520 - loss: 2.3891
# Epoch 89/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3146 - loss: 2.4283
# Epoch 90/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2613 - loss: 2.4192
# Epoch 91/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2994 - loss: 2.4236
# Epoch 92/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3068 - loss: 2.43841
# Epoch 93/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3341 - loss: 2.4068
# Epoch 94/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2911 - loss: 2.4092
# Epoch 95/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2911 - loss: 2.4115
# Epoch 96/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3224 - loss: 2.3791
# Epoch 97/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2847 - loss: 2.3598
# Epoch 98/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - accuracy: 0.2231 - loss: 2.4008
# Epoch 99/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2387 - loss: 2.3834
# Epoch 100/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3185 - loss: 2.3512
# Epoch 101/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2911 - loss: 2.3765
# Epoch 102/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2950 - loss: 2.3854
# Epoch 103/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2833 - loss: 2.3923
# Epoch 104/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2989 - loss: 2.4130
# Epoch 105/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2833 - loss: 2.3555
# Epoch 106/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2833 - loss: 2.3709
# Epoch 107/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3146 - loss: 2.3127
# Epoch 108/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3536 - loss: 2.2802
# Epoch 109/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3185 - loss: 2.3391
# Epoch 110/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3107 - loss: 2.3136
# Epoch 111/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3068 - loss: 2.3401
# Epoch 112/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3107 - loss: 2.3318
# Epoch 113/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3028 - loss: 2.32495
# Epoch 114/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3068 - loss: 2.2943
# Epoch 115/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3263 - loss: 2.2667
# Epoch 116/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3146 - loss: 2.2865
# Epoch 117/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3068 - loss: 2.2758
# Epoch 118/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2911 - loss: 2.2918
# Epoch 119/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2794 - loss: 2.3298
# Epoch 120/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2911 - loss: 2.2952
# Epoch 121/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3028 - loss: 2.3048
# Epoch 122/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2794 - loss: 2.3030
# Epoch 123/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2989 - loss: 2.2796
# Epoch 124/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3341 - loss: 2.2152
# Epoch 125/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3341 - loss: 2.2110
# Epoch 126/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3146 - loss: 2.2388
# Epoch 127/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3185 - loss: 2.24003
# Epoch 128/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2950 - loss: 2.2548
# Epoch 129/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3068 - loss: 2.2274
# Epoch 130/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3146 - loss: 2.2008
# Epoch 131/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3228 - loss: 2.1901
# Epoch 132/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2872 - loss: 2.2280
# Epoch 133/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - accuracy: 0.3185 - loss: 2.1979
# Epoch 134/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3224 - loss: 2.1629
# Epoch 135/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2989 - loss: 2.1914
# Epoch 136/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3028 - loss: 2.2034
# Epoch 137/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3068 - loss: 2.2174
# Epoch 138/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2755 - loss: 2.2430
# Epoch 139/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3302 - loss: 2.1671
# Epoch 140/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2872 - loss: 2.2432
# Epoch 141/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2755 - loss: 2.2342
# Epoch 142/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3380 - loss: 2.0921
# Epoch 143/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2911 - loss: 2.1937
# Epoch 144/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3362 - loss: 2.2059
# Epoch 145/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4237 - loss: 2.1634
# Epoch 146/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.4315 - loss: 2.1562
# Epoch 147/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3410 - loss: 2.1843
# Epoch 148/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2950 - loss: 2.1307
# Epoch 149/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3146 - loss: 2.0880
# Epoch 150/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3146 - loss: 2.0971
# Epoch 151/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3263 - loss: 2.0889
# Epoch 152/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4359 - loss: 2.0770
# Epoch 153/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4472 - loss: 2.0745
# Epoch 154/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4465 - loss: 2.0681
# Epoch 155/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4437 - loss: 2.0590
# Epoch 156/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3948 - loss: 2.0417
# Epoch 157/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4129 - loss: 2.0778
# Epoch 158/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4203 - loss: 2.1023
# Epoch 159/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3649 - loss: 2.0047
# Epoch 160/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3263 - loss: 2.0083
# Epoch 161/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3302 - loss: 2.0056
# Epoch 162/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3068 - loss: 2.0382
# Epoch 163/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4437 - loss: 2.0019
# Epoch 164/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4090 - loss: 2.0967
# Epoch 165/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4745 - loss: 1.9954
# Epoch 166/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3483 - loss: 2.0609
# Epoch 167/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2872 - loss: 2.0472
# Epoch 168/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3380 - loss: 1.9745
# Epoch 169/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.2833 - loss: 2.0643
# Epoch 170/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3028 - loss: 2.0200
# Epoch 171/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2716 - loss: 2.0852
# Epoch 172/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3146 - loss: 1.9895
# Epoch 173/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3146 - loss: 1.9928
# Epoch 174/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3068 - loss: 2.0154
# Epoch 175/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3068 - loss: 1.9829
# Epoch 176/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3228 - loss: 1.9618
# Epoch 177/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 276us/step - accuracy: 0.2872 - loss: 2.0135
# Epoch 178/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3263 - loss: 1.9641
# Epoch 179/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3068 - loss: 1.9821
# Epoch 180/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2716 - loss: 2.0402
# Epoch 181/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3185 - loss: 1.9303
# Epoch 182/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2716 - loss: 2.0312
# Epoch 183/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3028 - loss: 1.9335
# Epoch 184/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3263 - loss: 1.8944
# Epoch 185/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3380 - loss: 1.8771
# Epoch 186/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2989 - loss: 1.9203
# Epoch 187/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3146 - loss: 1.9296
# Epoch 188/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 227us/step - accuracy: 0.3380 - loss: 1.8927
# Epoch 189/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2716 - loss: 1.9662
# Epoch 190/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2911 - loss: 1.9567
# Epoch 191/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3341 - loss: 1.8965
# Epoch 192/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3302 - loss: 1.8888
# Epoch 193/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3146 - loss: 1.9027
# Epoch 194/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.2950 - loss: 1.9234
# Epoch 195/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3458 - loss: 1.8379
# Epoch 196/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3380 - loss: 1.8319
# Epoch 197/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3419 - loss: 1.8470
# Epoch 198/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3028 - loss: 1.8966
# Epoch 199/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2755 - loss: 1.9202
# Epoch 200/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3107 - loss: 1.8674
# Epoch 201/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3146 - loss: 1.8583
# Epoch 202/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 0.2950 - loss: 1.9026
# Epoch 203/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3185 - loss: 1.8013
# Epoch 204/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3302 - loss: 1.8228
# Epoch 205/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2950 - loss: 1.8548
# Epoch 206/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3107 - loss: 1.8689
# Epoch 207/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3146 - loss: 1.8298
# Epoch 208/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2989 - loss: 1.8263
# Epoch 209/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3380 - loss: 1.7577
# Epoch 210/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3341 - loss: 1.7522
# Epoch 211/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2677 - loss: 1.8959
# Epoch 212/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2989 - loss: 1.8401
# Epoch 213/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3068 - loss: 1.7714
# Epoch 214/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3185 - loss: 1.7732
# Epoch 215/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.3302 - loss: 1.7564
# Epoch 216/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2950 - loss: 1.8169
# Epoch 217/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3571 - loss: 1.7719
# Epoch 218/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4085 - loss: 1.8125
# Epoch 219/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4662 - loss: 1.7414
# Epoch 220/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3821 - loss: 1.7702
# Epoch 221/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4017 - loss: 1.7717
# Epoch 222/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3782 - loss: 1.7805
# Epoch 223/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3782 - loss: 1.7546
# Epoch 224/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4051 - loss: 1.7488
# Epoch 225/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4320 - loss: 1.7415
# Epoch 226/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4462 - loss: 1.7926
# Epoch 227/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4775 - loss: 1.7474
# Epoch 228/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4667 - loss: 1.6893
# Epoch 229/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3601 - loss: 1.7080
# Epoch 230/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3518 - loss: 1.7351
# Epoch 231/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3865 - loss: 1.7225
# Epoch 232/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.4099 - loss: 1.6888
# Epoch 233/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3670 - loss: 1.7068
# Epoch 234/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3718 - loss: 1.6497
# Epoch 235/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3366 - loss: 1.7121
# Epoch 236/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.4628 - loss: 1.6279
# Epoch 237/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4419 - loss: 1.7423
# Epoch 238/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4458 - loss: 1.7350
# Epoch 239/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4736 - loss: 1.6514
# Epoch 240/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4159 - loss: 1.7041
# Epoch 241/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4467 - loss: 1.6827
# Epoch 242/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4775 - loss: 1.6462
# Epoch 243/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5122 - loss: 1.5711
# Epoch 244/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.4770 - loss: 1.65513
# Epoch 245/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5312 - loss: 1.6184
# Epoch 246/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4883 - loss: 1.6435
# Epoch 247/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4770 - loss: 1.6440
# Epoch 248/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.4272 - loss: 1.6739
# Epoch 249/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4437 - loss: 1.6161
# Epoch 250/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4164 - loss: 1.6266
# Epoch 251/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5005 - loss: 1.5899
# Epoch 252/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4844 - loss: 1.6257
# Epoch 253/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5117 - loss: 1.5791
# Epoch 254/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5078 - loss: 1.5960
# Epoch 255/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.5234 - loss: 1.56186
# Epoch 256/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5195 - loss: 1.5663
# Epoch 257/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5386 - loss: 1.5651
# Epoch 258/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5152 - loss: 1.5659
# Epoch 259/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4883 - loss: 1.5832
# Epoch 260/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4609 - loss: 1.6583
# Epoch 261/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5034 - loss: 1.5550
# Epoch 262/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5005 - loss: 1.5374
# Epoch 263/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4853 - loss: 1.5063
# Epoch 264/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4545 - loss: 1.5377
# Epoch 265/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4540 - loss: 1.5313
# Epoch 266/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4662 - loss: 1.5091
# Epoch 267/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4697 - loss: 1.5252
# Epoch 268/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5039 - loss: 1.5195
# Epoch 269/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5381 - loss: 1.5199
# Epoch 270/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5634 - loss: 1.5203
# Epoch 271/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5958 - loss: 1.4324
# Epoch 272/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5680 - loss: 1.4812
# Epoch 273/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6149 - loss: 1.4360
# Epoch 274/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5915 - loss: 1.4540
# Epoch 275/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5788 - loss: 1.5095
# Epoch 276/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5949 - loss: 1.4649
# Epoch 277/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6023 - loss: 1.4738
# Epoch 278/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6140 - loss: 1.4540
# Epoch 279/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5558 - loss: 1.4737
# Epoch 280/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5910 - loss: 1.4421
# Epoch 281/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6105 - loss: 1.3773
# Epoch 282/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5528 - loss: 1.4515
# Epoch 283/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5715 - loss: 1.4457
# Epoch 284/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6062 - loss: 1.4262
# Epoch 285/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6057 - loss: 1.4591
# Epoch 286/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6222 - loss: 1.3386
# Epoch 287/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5577 - loss: 1.4137
# Epoch 288/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5671 - loss: 1.4447
# Epoch 289/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6213 - loss: 1.3868
# Epoch 290/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.6023 - loss: 1.3738
# Epoch 291/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6023 - loss: 1.3704
# Epoch 292/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6218 - loss: 1.3389
# Epoch 293/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6179 - loss: 1.3145
# Epoch 294/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6027 - loss: 1.3664
# Epoch 295/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5715 - loss: 1.3380
# Epoch 296/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6096 - loss: 1.3141
# Epoch 297/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6174 - loss: 1.3170
# Epoch 298/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - accuracy: 0.6232 - loss: 1.3879
# Epoch 299/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5629 - loss: 1.3546
# Epoch 300/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5494 - loss: 1.3283
# Epoch 301/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5338 - loss: 1.2912
# Epoch 302/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6296 - loss: 1.2970
# Epoch 303/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5788 - loss: 1.3208
# Epoch 304/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5676 - loss: 1.3598
# Epoch 305/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5519 - loss: 1.3220
# Epoch 306/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6135 - loss: 1.3201
# Epoch 307/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6468 - loss: 1.3419
# Epoch 308/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7011 - loss: 1.2498
# Epoch 309/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6399 - loss: 1.3101
# Epoch 310/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6746 - loss: 1.2531
# Epoch 311/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6365 - loss: 1.2617
# Epoch 312/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6482 - loss: 1.2301
# Epoch 313/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6321 - loss: 1.2583
# Epoch 314/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6248 - loss: 1.2537
# Epoch 315/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.6399 - loss: 1.2587
# Epoch 316/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6742 - loss: 1.2343
# Epoch 317/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6703 - loss: 1.2273
# Epoch 318/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6629 - loss: 1.2484
# Epoch 319/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6859 - loss: 1.1969
# Epoch 320/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7015 - loss: 1.1460
# Epoch 321/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6564 - loss: 1.2029
# Epoch 322/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6287 - loss: 1.1861
# Epoch 323/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5797 - loss: 1.1833
# Epoch 324/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5758 - loss: 1.1856
# Epoch 325/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5710 - loss: 1.2280
# Epoch 326/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6546 - loss: 1.1977
# Epoch 327/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6811 - loss: 1.2026
# Epoch 328/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7192 - loss: 1.1862
# Epoch 329/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.7353 - loss: 1.1628
# Epoch 330/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7314 - loss: 1.1372
# Epoch 331/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.7084 - loss: 1.1341
# Epoch 332/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.7006 - loss: 1.17699
# Epoch 333/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6967 - loss: 1.1542
# Epoch 334/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6967 - loss: 1.0950
# Epoch 335/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.6625 - loss: 1.1808
# Epoch 336/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.6199 - loss: 1.1652
# Epoch 337/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6239 - loss: 1.1739
# Epoch 338/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7158 - loss: 1.1248
# Epoch 339/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7192 - loss: 1.0904
# Epoch 340/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.7691 - loss: 1.1091
# Epoch 341/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7495 - loss: 1.0906
# Epoch 342/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7656 - loss: 1.0786
# Epoch 343/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7526 - loss: 1.06085
# Epoch 344/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7999 - loss: 1.0475
# Epoch 345/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7647 - loss: 1.1160
# Epoch 346/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7652 - loss: 1.0528
# Epoch 347/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7500 - loss: 1.0495
# Epoch 348/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7613 - loss: 1.0511
# Epoch 349/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7730 - loss: 1.0436
# Epoch 350/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7877 - loss: 1.0479
# Epoch 351/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7955 - loss: 1.0082
# Epoch 352/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8180 - loss: 1.0210
# Epoch 353/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8102 - loss: 1.0421
# Epoch 354/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8415 - loss: 1.0345
# Epoch 355/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7383 - loss: 1.0495
# Epoch 356/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7999 - loss: 0.9791
# Epoch 357/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8375 - loss: 1.0179
# Epoch 358/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8180 - loss: 1.0097
# Epoch 359/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8107 - loss: 0.9707
# Epoch 360/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8341 - loss: 0.9503
# Epoch 361/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8107 - loss: 0.9881
# Epoch 362/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8185 - loss: 0.9377
# Epoch 363/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8185 - loss: 0.9665
# Epoch 364/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7999 - loss: 0.9432
# Epoch 365/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8336 - loss: 0.9482
# Epoch 366/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7534 - loss: 0.9905
# Epoch 367/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7339 - loss: 1.0169
# Epoch 368/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7456 - loss: 0.9753
# Epoch 369/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7647 - loss: 0.9781
# Epoch 370/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7994 - loss: 0.9431
# Epoch 371/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7691 - loss: 0.9332
# Epoch 372/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7764 - loss: 0.9393
# Epoch 373/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8566 - loss: 0.8656
# Epoch 374/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8430 - loss: 0.9373
# Epoch 375/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8219 - loss: 0.8951
# Epoch 376/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8410 - loss: 0.9152
# Epoch 377/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8430 - loss: 0.9276
# Epoch 378/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8562 - loss: 0.8904
# Epoch 379/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8948 - loss: 0.8697
# Epoch 380/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8189 - loss: 0.8549
# Epoch 381/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7725 - loss: 0.9123
# Epoch 382/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8336 - loss: 0.8795
# Epoch 383/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8831 - loss: 0.8620
# Epoch 384/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8713 - loss: 0.8808
# Epoch 385/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8371 - loss: 0.8513
# Epoch 386/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8258 - loss: 0.8434
# Epoch 387/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7877 - loss: 0.8784
# Epoch 388/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7999 - loss: 0.8430
# Epoch 389/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7803 - loss: 0.8535
# Epoch 390/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8336 - loss: 0.8105
# Epoch 391/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8336 - loss: 0.8116
# Epoch 392/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8297 - loss: 0.8123
# Epoch 393/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.8150 - loss: 0.80068
# Epoch 394/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.8141 - loss: 0.8812
# Epoch 395/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8224 - loss: 0.8202
# Epoch 396/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.8102 - loss: 0.8398
# Epoch 397/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.8107 - loss: 0.8397
# Epoch 398/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.7642 - loss: 0.8554
# Epoch 399/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8635 - loss: 0.7952
# Epoch 400/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - accuracy: 0.8146 - loss: 0.8117
# Epoch 401/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8258 - loss: 0.7960
# Epoch 402/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8596 - loss: 0.8123
# Epoch 403/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8601 - loss: 0.8210
# Epoch 404/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8293 - loss: 0.8228
# Epoch 405/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.8483 - loss: 0.8120
# Epoch 406/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.8405 - loss: 0.8024
# Epoch 407/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8948 - loss: 0.7429
# Epoch 408/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8757 - loss: 0.7415
# Epoch 409/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8904 - loss: 0.7474
# Epoch 410/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8601 - loss: 0.7815
# Epoch 411/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8405 - loss: 0.77612
# Epoch 412/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8596 - loss: 0.7345
# Epoch 413/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8909 - loss: 0.7420
# Epoch 414/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8562 - loss: 0.7228
# Epoch 415/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8732 - loss: 0.7592
# Epoch 416/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8869 - loss: 0.7207
# Epoch 417/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8518 - loss: 0.7889
# Epoch 418/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8752 - loss: 0.7189
# Epoch 419/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8909 - loss: 0.7003
# Epoch 420/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8631 - loss: 0.7546
# Epoch 421/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8899 - loss: 0.7373
# Epoch 422/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8713 - loss: 0.7156
# Epoch 423/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8826 - loss: 0.7056
# Epoch 424/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8791 - loss: 0.6966
# Epoch 425/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8562 - loss: 0.6975
# Epoch 426/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8557 - loss: 0.7008
# Epoch 427/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8869 - loss: 0.6833
# Epoch 428/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8943 - loss: 0.6668
# Epoch 429/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8674 - loss: 0.6905
# Epoch 430/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.9090 - loss: 0.7083
# Epoch 431/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9090 - loss: 0.6660
# Epoch 432/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9090 - loss: 0.6839
# Epoch 433/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8938 - loss: 0.7213
# Epoch 434/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8605 - loss: 0.6663
# Epoch 435/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8405 - loss: 0.6914
# Epoch 436/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8674 - loss: 0.6514
# Epoch 437/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8327 - loss: 0.6813
# Epoch 438/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.8327 - loss: 0.6835
# Epoch 439/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.8679 - loss: 0.6480
# Epoch 440/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8601 - loss: 0.6390
# Epoch 441/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8601 - loss: 0.6530
# Epoch 442/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8904 - loss: 0.6479
# Epoch 443/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8982 - loss: 0.6188
# Epoch 444/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8631 - loss: 0.6943
# Epoch 445/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8748 - loss: 0.6733
# Epoch 446/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8787 - loss: 0.6696
# Epoch 447/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8787 - loss: 0.6338
# Epoch 448/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8635 - loss: 0.6161
# Epoch 449/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8791 - loss: 0.6329
# Epoch 450/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8215 - loss: 0.6534
# Epoch 451/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8713 - loss: 0.6123
# Epoch 452/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8631 - loss: 0.6509
# Epoch 453/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8631 - loss: 0.6737
# Epoch 454/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8977 - loss: 0.5997
# Epoch 455/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9056 - loss: 0.6087
# Epoch 456/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9095 - loss: 0.5829
# Epoch 457/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8977 - loss: 0.6025
# Epoch 458/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8977 - loss: 0.5848
# Epoch 459/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8977 - loss: 0.5955
# Epoch 460/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8865 - loss: 0.6101
# Epoch 461/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8899 - loss: 0.6128
# Epoch 462/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8865 - loss: 0.5953
# Epoch 463/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8899 - loss: 0.5883
# Epoch 464/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.8977 - loss: 0.5676
# Epoch 465/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8732 - loss: 0.5801
# Epoch 466/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8826 - loss: 0.5789
# Epoch 467/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8977 - loss: 0.5840
# Epoch 468/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8869 - loss: 0.5641
# Epoch 469/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.8943 - loss: 0.5687
# Epoch 470/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8748 - loss: 0.5862
# Epoch 471/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8977 - loss: 0.5540
# Epoch 472/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9173 - loss: 0.5579
# Epoch 473/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8787 - loss: 0.5674
# Epoch 474/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9017 - loss: 0.5394
# Epoch 475/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8596 - loss: 0.5935
# Epoch 476/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8938 - loss: 0.5734
# Epoch 477/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9056 - loss: 0.5246
# Epoch 478/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9095 - loss: 0.5122
# Epoch 479/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8899 - loss: 0.5398
# Epoch 480/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.8899 - loss: 0.5437
# Epoch 481/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8977 - loss: 0.5351
# Epoch 482/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8821 - loss: 0.5356
# Epoch 483/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8899 - loss: 0.5195
# Epoch 484/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9095 - loss: 0.5122
# Epoch 485/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8821 - loss: 0.5604
# Epoch 486/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9090 - loss: 0.4985
# Epoch 487/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9129 - loss: 0.5142
# Epoch 488/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9090 - loss: 0.4933
# Epoch 489/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9281 - loss: 0.4791
# Epoch 490/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8977 - loss: 0.4936
# Epoch 491/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - accuracy: 0.8977 - loss: 0.5181
# Epoch 492/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.9012 - loss: 0.52198
# Epoch 493/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - accuracy: 0.9252 - loss: 0.4869
# Epoch 494/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9168 - loss: 0.4824
# Epoch 495/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9129 - loss: 0.4964
# Epoch 496/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9012 - loss: 0.5269
# Epoch 497/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9168 - loss: 0.4699
# Epoch 498/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9056 - loss: 0.4711
# Epoch 499/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9056 - loss: 0.4676
# Epoch 500/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8899 - loss: 0.4723
# Epoch 501/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9056 - loss: 0.4639
# Epoch 502/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8899 - loss: 0.4976
# Epoch 503/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9056 - loss: 0.4265
# Epoch 504/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8821 - loss: 0.4880
# Epoch 505/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8821 - loss: 0.4805
# Epoch 506/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8857 - loss: 0.4464
# Epoch 507/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8899 - loss: 0.4675
# Epoch 508/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8899 - loss: 0.4552
# Epoch 509/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9056 - loss: 0.4517
# Epoch 510/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8977 - loss: 0.4758
# Epoch 511/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9017 - loss: 0.4373
# Epoch 512/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9168 - loss: 0.4391
# Epoch 513/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9168 - loss: 0.4373
# Epoch 514/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9090 - loss: 0.4605
# Epoch 515/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9246 - loss: 0.4320
# Epoch 516/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9090 - loss: 0.4365
# Epoch 517/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9207 - loss: 0.4224
# Epoch 518/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9099 - loss: 0.3875
# Epoch 519/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9012 - loss: 0.4522
# Epoch 520/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9203 - loss: 0.4363
# Epoch 521/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9012 - loss: 0.4195
# Epoch 522/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9090 - loss: 0.4368
# Epoch 523/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8934 - loss: 0.4394
# Epoch 524/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9285 - loss: 0.4016
# Epoch 525/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9203 - loss: 0.4307
# Epoch 526/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9359 - loss: 0.4107
# Epoch 527/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9472 - loss: 0.3891
# Epoch 528/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9320 - loss: 0.4151
# Epoch 529/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9398 - loss: 0.3935
# Epoch 530/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9359 - loss: 0.4201
# Epoch 531/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9281 - loss: 0.4042
# Epoch 532/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9203 - loss: 0.4034
# Epoch 533/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9437 - loss: 0.3721
# Epoch 534/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9090 - loss: 0.3856
# Epoch 535/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9168 - loss: 0.3935
# Epoch 536/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8973 - loss: 0.4130
# Epoch 537/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9095 - loss: 0.3624
# Epoch 538/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9281 - loss: 0.3836
# Epoch 539/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9320 - loss: 0.3919
# Epoch 540/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9281 - loss: 0.3638
# Epoch 541/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9550 - loss: 0.3552
# Epoch 542/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9623 - loss: 0.3739
# Epoch 543/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9320 - loss: 0.3663
# Epoch 544/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - accuracy: 0.9281 - loss: 0.3881
# Epoch 545/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9281 - loss: 0.3721
# Epoch 546/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9203 - loss: 0.3534
# Epoch 547/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9472 - loss: 0.3524
# Epoch 548/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9315 - loss: 0.3884
# Epoch 549/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9393 - loss: 0.3695
# Epoch 550/550
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9393 - loss: 0.3594

# %% [markdown]
# ### Saving the Model and Preprocessing Objects
#
# This section of the code is responsible for saving the trained model and essential preprocessing components (the tokenizer and label encoder) to disk, allowing the chatbot to be used later without requiring retraining.
#
# 1. **Saving the Model**:
#    The trained model is saved in the HDF5 format (`.h5`). This file contains all the details about the model, including its architecture, learned weights, and training configurations. Saving the model in this format ensures that it can be reloaded and used for making predictions in future sessions without needing to retrain.
#
# 2. **Saving the Tokenizer**:
#    The tokenizer, which is responsible for converting words into numerical representations (word indices), is saved to a file using the `pickle` module. This allows for consistent text preprocessing when the model is reloaded, ensuring that any input text is tokenized in the same way as during training.
#
# 3. **Saving the Label Encoder**:
#    The label encoder, which is used to transform categorical labels (such as different intents) into numeric values, is also saved to a file using `pickle`. This ensures that when the model is reloaded, the same label encoding is used to map predictions back to the correct intent labels.
#
# By saving the model, tokenizer, and label encoder, the system can be efficiently restored, and the chatbot can continue to make predictions without needing to retrain or reprocess the input data.

# %%
# saving model
model.save("chat_model.h5")

import pickle

# saving tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    

# saving label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
